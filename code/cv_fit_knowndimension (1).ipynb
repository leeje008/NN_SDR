# %%
from data_generator import *
from init_sdr import *
from main import *
from common import *
from measure import *

from cv_model import *
from test_model import *

import json

# %%
import ray
import time
import warnings

import torch
import argparse
import ray
from ray import tune
from ray.tune import Trainable
from itertools import product
import itertools

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split, Dataset, Subset
from torchvision import datasets, transforms

import ray
import copy


import time

from sklearn.model_selection import KFold

import argparse

import shutil

import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.tune.search import ConcurrencyLimiter
from typing import List, Dict

from ray.tune import CLIReporter
import warnings

from ray.tune.search.bayesopt import BayesOptSearch


import math

# %%
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from ray.tune.schedulers import HyperBandScheduler
import shutil

# %% [markdown]
# ## 일단은 Xaiver로

# %%
import time
start_time = time.time()
warnings.filterwarnings("ignore", category=UserWarning)


ray.init(ignore_reinit_error= True)

num_var = 20

hyper_space = {"h_dim1": 1,
             'h_dim2': num_var ,
             "sample_size": 500,
             "num_features": num_var,
             "lambda_0":  tune.grid_search([1e-3,5e-3,1e-2,5e-2]),
             'lr':  tune.grid_search([1e-4, 2.5e-4, 5e-4, 7.5e-4 ,1e-3, 2.5e-3, 5e-3, 7.5e-3, 1e-2, 2.5e-2, 5e-2, 7.5e-2, 1e-1, 2.5e-1, 5e-1, 7.5e-1]),
             'epoch':  1000,
             'seed': -1,
             "model_num": 'model1',
             "num_cv": 5,
             "or_pen": tune.grid_search(['pro', 'orthogonal']),
             "dim" : 'known'
}

local_dir = 'cv_0419/'
exp_name = "bn_transform"

study = tune.run(
        cv_train_model,
        config=hyper_space, 
        resources_per_trial={"cpu": 2}, 
        metric = 'cv_custom_loss' ,
        mode = 'min',
        raise_on_failed_trial=False, 
        verbose =  False 
)

best_trial = study.get_best_trial(metric="cv_custom_loss", mode = 'min')

ray.shutdown()

end_time = time.time()
execution_time = (end_time - start_time) / 60

print("Execution time:", execution_time, "minutes")
print('-' * 200)
# Out:
# (cv_train_model pid=689773) lambda0: 0.001 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen pro
# (cv_train_model pid=689773) cv_val_mse: 0.9911726713180542
# (cv_train_model pid=689773)  cv_custom_loss 0.991893881559372
# (cv_train_model pid=689798) lambda0: 0.005 lr:  0.1 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen pro [repeated 53x across cluster]
# (cv_train_model pid=689798) cv_val_mse: 1.5876258850097655  [repeated 53x across cluster]
# (cv_train_model pid=689798)  cv_custom_loss 1.5880348086357117 [repeated 53x across cluster]
# (cv_train_model pid=689773) lambda0: 0.001 lr:  0.5 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen pro [repeated 3x across cluster]
# (cv_train_model pid=689773) cv_val_mse: 33.316124725341794  [repeated 3x across cluster]
# (cv_train_model pid=689773)  cv_custom_loss 33.31615676879883 [repeated 3x across cluster]
# (cv_train_model pid=689786) lambda0: 0.05 lr:  0.00025 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen orthogonal
# (cv_train_model pid=689751) lambda0: 0.005 lr:  0.75 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen pro [repeated 7x across cluster]
# (cv_train_model pid=689802) cv_val_mse: 0.8022999882698059  [repeated 49x across cluster]
# (cv_train_model pid=689802)  cv_custom_loss 0.8044088304042816 [repeated 49x across cluster]
# (cv_train_model pid=689793) lambda0: 0.001 lr:  0.075 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen orthogonal [repeated 44x across cluster]
# (cv_train_model pid=689782) cv_val_mse: 0.8013399422168732  [repeated 4x across cluster]
# (cv_train_model pid=689782)  cv_custom_loss 0.8015183269977569 [repeated 4x across cluster]
# (cv_train_model pid=689795) lambda0: 0.05 lr:  0.025 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen orthogonal [repeated 3x across cluster]
# (cv_train_model pid=689795) cv_val_mse: 0.8234847009181976  [repeated 2x across cluster]
# (cv_train_model pid=689795)  cv_custom_loss 0.8348026275634766 [repeated 2x across cluster]
# (cv_train_model pid=689789)  cv_custom_loss 1.1012572407722474
# (cv_train_model pid=689789)  cv_custom_loss 1.1012572407722474
# (cv_train_model pid=689789)  cv_custom_loss 1.1012572407722474
# (cv_train_model pid=689773) lambda0: 0.01 lr:  0.075 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen orthogonal
# (cv_train_model pid=689773) cv_val_mse: 1.388404369354248
# (cv_train_model pid=689773)  cv_custom_loss 1.3927451014518737
# (cv_train_model pid=689749) lambda0: 0.001 lr:  0.5 h_dim2: 20 Epochs 1000 est_dim: 1.0 or_pen orthogonal [repeated 14x across cluster]
# (cv_train_model pid=689749) cv_val_mse: 33.3623161315918  [repeated 14x across cluster]
# (cv_train_model pid=689749)  cv_custom_loss 33.3623161315918 [repeated 14x across cluster]
# Execution time: 2.1610933462778728 minutes
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
best_config = best_trial.config
print("Best Hyperparameters:", best_config)
# Out:
# Best Hyperparameters: {'h_dim1': 1, 'h_dim2': 20, 'sample_size': 500, 'num_features': 20, 'lambda_0': 0.005, 'lr': 0.025, 'epoch': 1000, 'seed': -1, 'model_num': 'model1', 'num_cv': 5, 'or_pen': 'pro', 'dim': 'known'}

# %%
best_loss = best_trial.last_result["cv_custom_loss"]
print("Best Loss:", best_loss)
# Out:
# Best Loss: 0.6303766280412674

# %%
trials_df = study.dataframe()

print(trials_df.info())

trials_df.to_csv('fixed_d_cv_results/model8.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cv_val_mse                128 non-null    float64
#  1   cv_custom_loss            128 non-null    float64
#  2   time_this_iter_s          128 non-null    float64
#  3   done                      128 non-null    bool
#  4   timesteps_total           0 non-null      float64
#  5   episodes_total            0 non-null      float64
#  6   training_iteration        128 non-null    int64
#  7   trial_id                  128 non-null    object
#  8   experiment_id             128 non-null    object
#  9   date                      128 non-null    object
#  10  timestamp                 128 non-null    int64
#  11  time_total_s              128 non-null    float64
#  12  pid                       128 non-null    int64
#  13  hostname                  128 non-null    object
#  14  node_ip                   128 non-null    object
#  15  time_since_restore        128 non-null    float64
#  16  timesteps_since_restore   128 non-null    int64
#  17  iterations_since_restore  128 non-null    int64
#  18  warmup_time               128 non-null    float64
#  19  config/dim                128 non-null    object
#  20  config/epoch              128 non-null    int64
#  21  config/h_dim1             128 non-null    int64
#  22  config/h_dim2             128 non-null    int64
#  23  config/lambda_0           128 non-null    float64
#  24  config/lr                 128 non-null    float64
#  25  config/model_num          128 non-null    object
#  26  config/num_cv             128 non-null    int64
#  27  config/num_features       128 non-null    int64
#  28  config/or_pen             128 non-null    object
#  29  config/sample_size        128 non-null    int64
#  30  config/seed               128 non-null    int64
#  31  logdir                    128 non-null    object
# dtypes: bool(1), float64(10), int64(12), object(9)
# memory usage: 31.2+ KB
# None

# %%
trials_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cv_val_mse                128 non-null    float64
#  1   cv_custom_loss            128 non-null    float64
#  2   time_this_iter_s          128 non-null    float64
#  3   done                      128 non-null    bool
#  4   timesteps_total           0 non-null      float64
#  5   episodes_total            0 non-null      float64
#  6   training_iteration        128 non-null    int64
#  7   trial_id                  128 non-null    object
#  8   experiment_id             128 non-null    object
#  9   date                      128 non-null    object
#  10  timestamp                 128 non-null    int64
#  11  time_total_s              128 non-null    float64
#  12  pid                       128 non-null    int64
#  13  hostname                  128 non-null    object
#  14  node_ip                   128 non-null    object
#  15  time_since_restore        128 non-null    float64
#  16  timesteps_since_restore   128 non-null    int64
#  17  iterations_since_restore  128 non-null    int64
#  18  warmup_time               128 non-null    float64
#  19  config/dim                128 non-null    object
#  20  config/epoch              128 non-null    int64
#  21  config/h_dim1             128 non-null    int64
#  22  config/h_dim2             128 non-null    int64
#  23  config/lambda_0           128 non-null    float64
#  24  config/lr                 128 non-null    float64
#  25  config/model_num          128 non-null    object
#  26  config/num_cv             128 non-null    int64
#  27  config/num_features       128 non-null    int64
#  28  config/or_pen             128 non-null    object
#  29  config/sample_size        128 non-null    int64
#  30  config/seed               128 non-null    int64
#  31  logdir                    128 non-null    object
# dtypes: bool(1), float64(10), int64(12), object(9)
# memory usage: 31.2+ KB

# %%
import time
start_time = time.time()


ray.init(ignore_reinit_error=True)

warnings.filterwarnings("ignore", category=UserWarning)

num_var = 20

hyper_space = {"h_dim1":1,
             'h_dim2': num_var ,
             "sample_size": 1000,
             "num_features": num_var,
             "lambda_0":  tune.grid_search([1e-3, 5e-3,0.01, 0.05, 0.07, 0.1, 0.5]),
             'lambda_1': tune.grid_search([0.1]),
             'lr':  tune.grid_search([1e-2, 5e-2, 1e-3, 5e-3, 1e-4, 5e-4, 1e-5, 5e-5]),
             'epoch':  1000,
             'seed': -1,
             "model_num": 'model4',
             "num_cv": 5,
             "or_pen": tune.grid_search(['pro', 'orthogonal']),
             "dim" : 'known'
}

local_dir = 'cv_0419/'
exp_name = "bn_transform"

study1 = tune.run(
        cv_train_model,
        config=hyper_space, 
        resources_per_trial={"cpu": 32}, 
        metric = 'cv_custom_loss' ,
        mode = 'min',
        raise_on_failed_trial=False, 
        verbose =  False 
)

best_config2 = study1.get_best_config(metric="cv_custom_loss", mode = 'min')

ray.shutdown()

end_time = time.time()
execution_time = (end_time - start_time) / 60

print("Execution time:", execution_time, "minutes")
print('-' * 200)
print(best_config2)
# Out:
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.849621868133545
# (cv_train_model pid=1248861)  cv_custom_loss 1.8534056186676025
# (cv_train_model pid=1248865) lambda0: 0.005 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.8506564378738404
# (cv_train_model pid=1248865)  cv_custom_loss 1.8701382637023927
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.858734405040741
# (cv_train_model pid=1248866)  cv_custom_loss 1.8924262046813964
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.8294134140014648
# (cv_train_model pid=1248866)  cv_custom_loss 2.1936015605926515
# (cv_train_model pid=1248865) lambda0: 0.07 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.8397209882736205
# (cv_train_model pid=1248865)  cv_custom_loss 2.09505717754364
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.834332489967346
# (cv_train_model pid=1248861)  cv_custom_loss 2.0159969091415406
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.7921071529388428
# (cv_train_model pid=1248865)  cv_custom_loss 1.8113983154296875
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.8699555158615113
# (cv_train_model pid=1248866)  cv_custom_loss 3.9597450733184814
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.7881609916687011
# (cv_train_model pid=1248861)  cv_custom_loss 1.884039044380188
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.7830697774887085
# (cv_train_model pid=1248865)  cv_custom_loss 1.9706748723983765
# (cv_train_model pid=1248866) lambda0: 0.05 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.7821836471557617
# (cv_train_model pid=1248866)  cv_custom_loss 2.7502116680145265
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.7906272411346436
# (cv_train_model pid=1248861)  cv_custom_loss 3.132327699661255
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.7865475177764893
# (cv_train_model pid=1248865)  cv_custom_loss 3.691405200958252
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.791597604751587
# (cv_train_model pid=1248866)  cv_custom_loss 11.789985847473144
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 4.847658300399781
# (cv_train_model pid=1248861)  cv_custom_loss 4.847712469100952
# (cv_train_model pid=1248865) lambda0: 0.005 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 4.8561371803283695
# (cv_train_model pid=1248865)  cv_custom_loss 4.856398868560791
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 4.839456462860108
# (cv_train_model pid=1248866)  cv_custom_loss 4.839971446990967
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 4.829024362564087
# (cv_train_model pid=1248861)  cv_custom_loss 4.831633377075195
# (cv_train_model pid=1248865) lambda0: 0.07 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 4.841244125366211
# (cv_train_model pid=1248865)  cv_custom_loss 4.844977617263794
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 4.829195976257324
# (cv_train_model pid=1248866)  cv_custom_loss 4.834511137008667
# (cv_train_model pid=1248861) lambda0: 0.5 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 4.888878726959229
# (cv_train_model pid=1248861)  cv_custom_loss 4.916388893127442
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.9336360454559327
# (cv_train_model pid=1248865)  cv_custom_loss 1.9354001998901367
# (cv_train_model pid=1248866) lambda0: 0.005 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.946840476989746
# (cv_train_model pid=1248866)  cv_custom_loss 1.9556609869003296
# (cv_train_model pid=1248861) lambda0: 0.01 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.9539909362792969
# (cv_train_model pid=1248861)  cv_custom_loss 1.9730866193771361
# (cv_train_model pid=1248865) lambda0: 0.05 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.9528342008590698
# (cv_train_model pid=1248865)  cv_custom_loss 2.03949236869812
# (cv_train_model pid=1248866) lambda0: 0.07 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 1.9502009749412537
# (cv_train_model pid=1248866)  cv_custom_loss 2.073568141460419
# (cv_train_model pid=1248861) lambda0: 0.1 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 1.9435149669647216
# (cv_train_model pid=1248861)  cv_custom_loss 2.1145455121994017
# (cv_train_model pid=1248865) lambda0: 0.5 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 1.9641127109527587
# (cv_train_model pid=1248865)  cv_custom_loss 2.7857143878936768
# (cv_train_model pid=1248866) lambda0: 0.001 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 8.697678279876708
# (cv_train_model pid=1248866)  cv_custom_loss 8.697994136810303
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 8.75696678161621
# (cv_train_model pid=1248861)  cv_custom_loss 8.758549404144286
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 8.782617092132568
# (cv_train_model pid=1248865)  cv_custom_loss 8.785933494567871
# (cv_train_model pid=1248866) lambda0: 0.05 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 8.73081407546997
# (cv_train_model pid=1248866)  cv_custom_loss 8.748035907745361
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 8.589829063415527
# (cv_train_model pid=1248861)  cv_custom_loss 8.613205337524414
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 8.681153964996337
# (cv_train_model pid=1248865)  cv_custom_loss 8.713055992126465
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 8.764204502105713
# (cv_train_model pid=1248866)  cv_custom_loss 8.968413162231446
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 6.860243034362793
# (cv_train_model pid=1248861)  cv_custom_loss 6.860731697082519
# (cv_train_model pid=1248865) lambda0: 0.005 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 6.840963840484619
# (cv_train_model pid=1248865)  cv_custom_loss 6.843083095550537
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 6.8160374641418455
# (cv_train_model pid=1248866)  cv_custom_loss 6.821113586425781
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 6.727519273757935
# (cv_train_model pid=1248861)  cv_custom_loss 6.748601579666138
# (cv_train_model pid=1248865) lambda0: 0.07 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 6.801550483703613
# (cv_train_model pid=1248865)  cv_custom_loss 6.835933780670166
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 6.846234130859375
# (cv_train_model pid=1248866)  cv_custom_loss 6.897600936889648
# (cv_train_model pid=1248861) lambda0: 0.5 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 6.7891161918640135
# (cv_train_model pid=1248861)  cv_custom_loss 7.02906608581543
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 11.043645858764648
# (cv_train_model pid=1248865)  cv_custom_loss 11.044395637512206
# (cv_train_model pid=1248866) lambda0: 0.005 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 11.008602523803711
# (cv_train_model pid=1248866)  cv_custom_loss 11.012301445007324
# (cv_train_model pid=1248861) lambda0: 0.01 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 11.083195018768311
# (cv_train_model pid=1248861)  cv_custom_loss 11.090601921081543
# (cv_train_model pid=1248865) lambda0: 0.05 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 11.034944152832031
# (cv_train_model pid=1248865)  cv_custom_loss 11.072029113769531
# (cv_train_model pid=1248866) lambda0: 0.07 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 11.056490707397462
# (cv_train_model pid=1248866)  cv_custom_loss 11.108410453796386
# (cv_train_model pid=1248861) lambda0: 0.1 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 11.028767204284668
# (cv_train_model pid=1248861)  cv_custom_loss 11.104405212402344
# (cv_train_model pid=1248865) lambda0: 0.5 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 11.009423828125
# (cv_train_model pid=1248865)  cv_custom_loss 11.393552780151367
# (cv_train_model pid=1248866) lambda0: 0.001 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 9.823283004760743
# (cv_train_model pid=1248866)  cv_custom_loss 9.823888778686523
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 9.914406013488769
# (cv_train_model pid=1248861)  cv_custom_loss 9.917486953735352
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 9.865629482269288
# (cv_train_model pid=1248865)  cv_custom_loss 9.871300601959229
# (cv_train_model pid=1248866) lambda0: 0.05 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 9.829841423034669
# (cv_train_model pid=1248866)  cv_custom_loss 9.858835601806641
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248861) cv_val_mse: 9.848034286499024
# (cv_train_model pid=1248861)  cv_custom_loss 9.887657260894775
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248865) cv_val_mse: 9.864971160888672
# (cv_train_model pid=1248865)  cv_custom_loss 9.930105495452882
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen pro
# (cv_train_model pid=1248866) cv_val_mse: 9.836333847045898
# (cv_train_model pid=1248866)  cv_custom_loss 10.169213390350341
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.8490582942962646
# (cv_train_model pid=1248861)  cv_custom_loss 1.8667468786239625
# (cv_train_model pid=1248865) lambda0: 0.005 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.8291358709335328
# (cv_train_model pid=1248865)  cv_custom_loss 1.9156769394874573
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.8454062223434449
# (cv_train_model pid=1248866)  cv_custom_loss 2.032700204849243
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.8313704967498778
# (cv_train_model pid=1248861)  cv_custom_loss 2.677507734298706
# (cv_train_model pid=1248865) lambda0: 0.07 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.836569356918335
# (cv_train_model pid=1248865)  cv_custom_loss 3.1051845073699953
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.8249127388000488
# (cv_train_model pid=1248866)  cv_custom_loss 3.4872958183288576
# (cv_train_model pid=1248861) lambda0: 0.5 lambda1:  0.1 lr:  0.01 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.8411590695381164
# (cv_train_model pid=1248861)  cv_custom_loss 10.55759506225586
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.7969398975372315
# (cv_train_model pid=1248865)  cv_custom_loss 1.8741288661956788
# (cv_train_model pid=1248866) lambda0: 0.005 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.7801834344863892
# (cv_train_model pid=1248866)  cv_custom_loss 2.1447869777679442
# (cv_train_model pid=1248861) lambda0: 0.01 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.7941059827804566
# (cv_train_model pid=1248861)  cv_custom_loss 2.5306416511535645
# (cv_train_model pid=1248865) lambda0: 0.05 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.7898705840110778
# (cv_train_model pid=1248865)  cv_custom_loss 5.379314231872558
# (cv_train_model pid=1248866) lambda0: 0.07 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.7995930433273315
# (cv_train_model pid=1248866)  cv_custom_loss 6.971258163452148
# (cv_train_model pid=1248861) lambda0: 0.1 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.8267532587051392
# (cv_train_model pid=1248861)  cv_custom_loss 9.863101291656495
# (cv_train_model pid=1248865) lambda0: 0.5 lambda1:  0.1 lr:  0.05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.7980891704559325
# (cv_train_model pid=1248865)  cv_custom_loss 37.80699195861816
# (cv_train_model pid=1248866) lambda0: 0.001 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 4.878083324432373
# (cv_train_model pid=1248866)  cv_custom_loss 4.879487705230713
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 4.955309295654297
# (cv_train_model pid=1248861)  cv_custom_loss 4.962857437133789
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 4.8415569305419925
# (cv_train_model pid=1248865)  cv_custom_loss 4.855435180664062
# (cv_train_model pid=1248866) lambda0: 0.05 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 4.836271667480469
# (cv_train_model pid=1248866)  cv_custom_loss 4.90440878868103
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 4.872423315048218
# (cv_train_model pid=1248865)  cv_custom_loss 5.014495992660523
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 4.8438804149627686
# (cv_train_model pid=1248861)  cv_custom_loss 4.940771961212159
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  0.001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 4.847461795806884
# (cv_train_model pid=1248866)  cv_custom_loss 5.543224334716797
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.9816606044769287
# (cv_train_model pid=1248865)  cv_custom_loss 1.9908047914505005
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.935994291305542
# (cv_train_model pid=1248861)  cv_custom_loss 1.9863500356674195
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.9628052234649658
# (cv_train_model pid=1248866)  cv_custom_loss 2.062750220298767
# (cv_train_model pid=1248865) lambda0: 0.05 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.9570870399475098
# (cv_train_model pid=1248865)  cv_custom_loss 2.441160249710083
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 1.9528321743011474
# (cv_train_model pid=1248861)  cv_custom_loss 2.6415796756744383
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 1.9526881933212281
# (cv_train_model pid=1248866)  cv_custom_loss 2.9079874992370605
# (cv_train_model pid=1248865) lambda0: 0.5 lambda1:  0.1 lr:  0.005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 1.9683283567428589
# (cv_train_model pid=1248865)  cv_custom_loss 6.888584232330322
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 8.702828693389893
# (cv_train_model pid=1248861)  cv_custom_loss 8.702854347229003
# (cv_train_model pid=1248866) lambda0: 0.005 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 8.695417976379394
# (cv_train_model pid=1248866)  cv_custom_loss 8.69558401107788
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 8.716685009002685
# (cv_train_model pid=1248865)  cv_custom_loss 8.71725378036499
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 8.70524730682373
# (cv_train_model pid=1248861)  cv_custom_loss 8.708190822601319
# (cv_train_model pid=1248866) lambda0: 0.07 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 8.711490058898926
# (cv_train_model pid=1248866)  cv_custom_loss 8.714174270629883
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 8.728356552124023
# (cv_train_model pid=1248865)  cv_custom_loss 8.732268810272217
# (cv_train_model pid=1248861) lambda0: 0.5 lambda1:  0.1 lr:  0.0001 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 8.794080448150634
# (cv_train_model pid=1248861)  cv_custom_loss 8.812396335601807
# (cv_train_model pid=1248866) lambda0: 0.001 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 6.846211242675781
# (cv_train_model pid=1248866)  cv_custom_loss 6.849701309204102
# (cv_train_model pid=1248865) lambda0: 0.005 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 6.772159004211426
# (cv_train_model pid=1248865)  cv_custom_loss 6.789849376678466
# (cv_train_model pid=1248861) lambda0: 0.01 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 6.75634355545044
# (cv_train_model pid=1248861)  cv_custom_loss 6.791632747650146
# (cv_train_model pid=1248866) lambda0: 0.05 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 6.838048648834229
# (cv_train_model pid=1248866)  cv_custom_loss 7.013907051086425
# (cv_train_model pid=1248865) lambda0: 0.07 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 6.779605388641357
# (cv_train_model pid=1248865)  cv_custom_loss 7.025079536437988
# (cv_train_model pid=1248861) lambda0: 0.1 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 6.841695880889892
# (cv_train_model pid=1248861)  cv_custom_loss 7.2132237434387205
# (cv_train_model pid=1248866) lambda0: 0.5 lambda1:  0.1 lr:  0.0005 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 6.787652778625488
# (cv_train_model pid=1248866)  cv_custom_loss 8.4793119430542
# (cv_train_model pid=1248865) lambda0: 0.001 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 11.016058826446534
# (cv_train_model pid=1248865)  cv_custom_loss 11.01636037826538
# (cv_train_model pid=1248861) lambda0: 0.005 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 11.04844036102295
# (cv_train_model pid=1248861)  cv_custom_loss 11.050337028503417
# (cv_train_model pid=1248866) lambda0: 0.01 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 11.043771362304687
# (cv_train_model pid=1248866)  cv_custom_loss 11.047263717651367
# (cv_train_model pid=1248865) lambda0: 0.05 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 11.07891845703125
# (cv_train_model pid=1248865)  cv_custom_loss 11.099147510528564
# (cv_train_model pid=1248861) lambda0: 0.07 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 11.071679592132568
# (cv_train_model pid=1248861)  cv_custom_loss 11.095476150512695
# (cv_train_model pid=1248866) lambda0: 0.1 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 11.052533912658692
# (cv_train_model pid=1248866)  cv_custom_loss 11.092558670043946
# (cv_train_model pid=1248865) lambda0: 0.5 lambda1:  0.1 lr:  1e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 11.026949310302735
# (cv_train_model pid=1248865)  cv_custom_loss 11.213373947143555
# (cv_train_model pid=1248861) lambda0: 0.001 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 9.874047183990479
# (cv_train_model pid=1248861)  cv_custom_loss 9.87415657043457
# (cv_train_model pid=1248866) lambda0: 0.005 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 9.869572639465332
# (cv_train_model pid=1248866)  cv_custom_loss 9.870534324645996
# (cv_train_model pid=1248865) lambda0: 0.01 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 9.85138463973999
# (cv_train_model pid=1248865)  cv_custom_loss 9.853221607208251
# (cv_train_model pid=1248861) lambda0: 0.05 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 9.852258491516114
# (cv_train_model pid=1248861)  cv_custom_loss 9.859516811370849
# (cv_train_model pid=1248866) lambda0: 0.07 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248866) cv_val_mse: 9.825024127960205
# (cv_train_model pid=1248866)  cv_custom_loss 9.837812328338623
# (cv_train_model pid=1248865) lambda0: 0.1 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248865) cv_val_mse: 9.850212287902831
# (cv_train_model pid=1248865)  cv_custom_loss 9.871356773376466
# (cv_train_model pid=1248861) lambda0: 0.5 lambda1:  0.1 lr:  5e-05 h_dim2: 20 Epochs 1000 est_dim:  1.0 or_pen orthogonal
# (cv_train_model pid=1248861) cv_val_mse: 9.855888557434081
# (cv_train_model pid=1248861)  cv_custom_loss 9.941477584838868
# Execution time: 35.52977356513341 minutes
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# {'h_dim1': 1, 'h_dim2': 20, 'sample_size': 1000, 'num_features': 20, 'lambda_0': 0.001, 'lambda_1': 0.1, 'lr': 0.05, 'epoch': 1000, 'seed': -1, 'model_num': 'model4', 'num_cv': 5, 'or_pen': 'pro', 'dim': 'known'}
